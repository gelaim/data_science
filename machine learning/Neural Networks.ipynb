# %% [markdown]
# # Neural Networks
#
# A Neural network consist of nodes and connections between nodes.
# A node is also known as an artificial neuron, and it has an associated weight and threshold.
# If the output of a node is above the threshold, it will send data to connected nodes.

# %% [markdown]
# ## Activation Funcions
# Sigmoid:
#
# ![image.png](attachment:620ddcd0-43a3-4981-9523-0c16c20cf2a2.png)
#
# <img src="attachment:1c77bd00-231b-4611-baa5-a086c3cc7552.png" alt="Drawing" style="width: 200px;"/>
#
#
# Tanh:
#
# ![image.png](attachment:b59f64d1-bede-4fc7-85ac-020aaf6c5f61.png)
#
# <img src="attachment:6a9fa002-707c-49eb-945a-705178812edc.png" alt="Drawing" style="width: 200px;"/>
#
# ReLU:
#
# ![image.png](attachment:7b2c7c80-b1fb-470a-8769-021d6e4defd7.png)
#
# <img src="attachment:08b60ca0-ff7a-43ff-b6d8-b6da9db77d5a.png" alt="Drawing" style="width: 200px;"/>

# %% [markdown]
# ## MLP
#
# TODO
